# %%
! pip install -q kaggle

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-454209ea-c7a4-4a27-afce-40f8320bdc97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-454209ea-c7a4-4a27-afce-40f8320bdc97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# {'kaggle.json': b'{"username":"abanoubmaher","key":"9cff2f3afe257c6c089eec65a12153a0"}'}

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                                       title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# datasets/piterfm/2022-ukraine-russian-war                                 2022 Ukraine Russia War                               1KB  2022-03-24 09:08:51           2583        181  1.0
# datasets/prasertk/healthy-lifestyle-cities-report-2021                    Healthy Lifestyle Cities Report 2021                  2KB  2022-03-03 00:26:02           2849         94  1.0
# datasets/prasertk/netflix-daily-top-10-in-us                              Netflix daily top 10                                 70KB  2022-03-12 13:22:19           1267         35  1.0
# ...

# %%
# !kaggle datasets download -d tawsifurrahman/covid19-radiography-database
# Out:
# ...
# 100% 778M/778M [00:04<00:00, 223MB/s]
# 100% 778M/778M [00:04<00:00, 187MB/s]

# %%
! cp covid19-radiography-database.zip /content/gdrive/MyDrive/GP/ML/

# %%
# %cd gdrive/MyDrive/ML/
# Out:
# /content/gdrive/.shortcut-targets-by-id/18dU1rLgpQvebEJhVNBguM_6BKp5uFSH7/ML

# %%
# !ls
# Out:
# Covid-19_Detection.ipynb	  Covid.csv	 train_data.csv
# covid19-radiography-database.zip  Normal.csv	 ViralPneumonia.csv
# COVID-19_Radiography_Dataset	  test_data.csv

# %%
! unzip covid19-radiography-database.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7921.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7922.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7923.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7924.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7925.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7926.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7927.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7928.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7929.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-793.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7930.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7931.png
# ...

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
cd COVID-19_Radiography_Dataset/
# Out:
# /content/gdrive/MyDrive/GP/ML/COVID-19_Radiography_Dataset

# %%
# !ls
# Out:
#  COVID			      Normal.metadata.xlsx
#  COVID.metadata.xlsx	      README.md.txt
#  Lung_Opacity		     'Viral Pneumonia'
#  Lung_Opacity.metadata.xlsx  'Viral Pneumonia.metadata.xlsx'
#  Normal

# %%
# %cd ..
# Out:
# /content/gdrive/MyDrive/GP/ML

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
train_cov=pd.read_excel("./COVID-19_Radiography_Dataset/COVID.metadata.xlsx")
train_cov["label"]= "COVID"
train_nor=pd.read_excel("./COVID-19_Radiography_Dataset/Normal.metadata.xlsx").sample(4192)
train_nor["label"]= "NORMAL"
train_pneu=pd.read_excel("./COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx")
train_pneu["label"]= "PNEUMONIA"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-5eabec7d2f54> in <module>()
# ----> 1 train_cov=pd.read_excel("./COVID-19_Radiography_Dataset/COVID.metadata.xlsx")
#       2 train_cov["label"]= "COVID"
#       3 train_nor=pd.read_excel("./COVID-19_Radiography_Dataset/Normal.metadata.xlsx").sample(4192)
#       4 train_nor["label"]= "NORMAL"
#       5 train_pneu=pd.read_excel("./COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
train_nor.head()
# Out:
#         FILE NAME FORMAT     SIZE  \
# 9671  NORMAL-9672    PNG  256*256
# 7057  NORMAL-7058    PNG  256*256
# 4239  NORMAL-4240    PNG  256*256
# 7229  NORMAL-7230    PNG  256*256
# 8153  NORMAL-8154    PNG  256*256
#
#                                                     URL   label
# 9671  https://www.kaggle.com/paultimothymooney/chest...  NORMAL
# 7057  https://www.kaggle.com/c/rsna-pneumonia-detect...  NORMAL
# 4239  https://www.kaggle.com/c/rsna-pneumonia-detect...  NORMAL
# 7229  https://www.kaggle.com/c/rsna-pneumonia-detect...  NORMAL
# 8153  https://www.kaggle.com/c/rsna-pneumonia-detect...  NORMAL

# %%
train_cov.head()
# Out:
#   FILE NAME FORMAT     SIZE  \
# 0   COVID-1    PNG  256*256
# 1   COVID-2    PNG  256*256
# 2   COVID-3    PNG  256*256
# 3   COVID-4    PNG  256*256
# 4   COVID-5    PNG  256*256
#
#                                                  URL  label
# 0  https://sirm.org/category/senza-categoria/covi...  COVID
# 1  https://sirm.org/category/senza-categoria/covi...  COVID
# 2  https://sirm.org/category/senza-categoria/covi...  COVID
# 3  https://sirm.org/category/senza-categoria/covi...  COVID
# 4  https://sirm.org/category/senza-categoria/covi...  COVID

# %%
train_pneu.head()
# Out:
#            FILE NAME FORMAT     SIZE  \
# 0  Viral Pneumonia-1    PNG  256*256
# 1  Viral Pneumonia-2    PNG  256*256
# 2  Viral Pneumonia-3    PNG  256*256
# 3  Viral Pneumonia-4    PNG  256*256
# 4  Viral Pneumonia-5    PNG  256*256
#
#                                                  URL      label
# 0  https://www.kaggle.com/paultimothymooney/chest...  PNEUMONIA
# 1  https://www.kaggle.com/paultimothymooney/chest...  PNEUMONIA
# 2  https://www.kaggle.com/paultimothymooney/chest...  PNEUMONIA
# 3  https://www.kaggle.com/paultimothymooney/chest...  PNEUMONIA
# 4  https://www.kaggle.com/paultimothymooney/chest...  PNEUMONIA

# %%
import os
import pandas as pd
y = 0
# os.walk --> return folders and files name
# './COVID-19_Radiography_Dataset/COVID'
dataCovid = []
for dirname, _, filenames in os.walk('./COVID-19_Radiography_Dataset/COVID'):
    for filename in filenames:
          dataCovid.append(os.path.join(dirname, filename))

dataViralPneumonia = []
for dirname, _, filenames in os.walk('./COVID-19_Radiography_Dataset/Viral Pneumonia'):
    for filename in filenames:
          dataViralPneumonia.append(os.path.join(dirname, filename))

dataNormal = []
for dirname, _, filenames in os.walk('./COVID-19_Radiography_Dataset/Normal'):
    for filename in filenames:
          dataNormal.append(os.path.join(dirname, filename))

# %%
dataNormal
# Out:
# ['./COVID-19_Radiography_Dataset/Normal/images/Normal-4108.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-10108.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-6885.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-9894.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-7889.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-3974.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-7642.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-9547.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-7233.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-3553.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-3158.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-1674.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-755.png',
#  './COVID-19_Radiography_Dataset/Normal/images/Normal-6719.png',
# ...

# %%
len(dataNormal)
# Out:
# 3018

# %%
len(dataCovid)
# Out:
# 7028

# %%
len(dataViralPneumonia)
# Out:
# 2653

# %%
df_covid = pd.DataFrame(dataCovid)
df_viralPneumonia = pd.DataFrame(dataViralPneumonia)
df_normal = pd.DataFrame(dataNormal)

# %%
df_covid.head()
# Out:
#                                                    0
# 0  ./COVID-19_Radiography_Dataset/COVID/masks/COV...
# 1  ./COVID-19_Radiography_Dataset/COVID/masks/COV...
# 2  ./COVID-19_Radiography_Dataset/COVID/masks/COV...
# 3  ./COVID-19_Radiography_Dataset/COVID/masks/COV...
# 4  ./COVID-19_Radiography_Dataset/COVID/masks/COV...

# %%
df_covid.rename(columns = {0:'images'}, inplace = True)
df_covid["target"] = "COVID-19"

df_viralPneumonia.rename(columns = {0:'images'}, inplace = True)
df_viralPneumonia["target"] = "ViralPneumonia"

df_normal.rename(columns = {0:'images'}, inplace = True)
df_normal["target"] = "Normal"

# %%
df_covid.head()
# Out:
#                                               images    target
# 0  ./COVID-19_Radiography_Dataset/COVID/masks/COV...  COVID-19
# 1  ./COVID-19_Radiography_Dataset/COVID/masks/COV...  COVID-19
# 2  ./COVID-19_Radiography_Dataset/COVID/masks/COV...  COVID-19
# 3  ./COVID-19_Radiography_Dataset/COVID/masks/COV...  COVID-19
# 4  ./COVID-19_Radiography_Dataset/COVID/masks/COV...  COVID-19

# %%
df_normal.head()
# Out:
#                                               images  target
# 0  ./COVID-19_Radiography_Dataset/Normal/images/N...  Normal
# 1  ./COVID-19_Radiography_Dataset/Normal/images/N...  Normal
# 2  ./COVID-19_Radiography_Dataset/Normal/images/N...  Normal
# 3  ./COVID-19_Radiography_Dataset/Normal/images/N...  Normal
# 4  ./COVID-19_Radiography_Dataset/Normal/images/N...  Normal

# %%
df_viralPneumonia.head()
# Out:
#                                               images          target
# 0  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 1  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 2  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 3  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 4  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia

# %%
#saving (df)paths in csv files
df_covid.to_csv('Covid.csv')
df_normal.to_csv('Normal.csv')
df_viralPneumonia.to_csv('ViralPneumonia.csv')

# %%
# !ls
# Out:
# Covid-19_Detection.ipynb	  Covid.csv	 train_data.csv
# covid19-radiography-database.zip  Normal.csv	 ViralPneumonia.csv
# COVID-19_Radiography_Dataset	  test_data.csv

# %%
import math

test_data_idx = math.ceil(df_covid.shape[0]/4)
train_covid = df_covid.iloc[test_data_idx:]
test_covid = df_covid.iloc[:test_data_idx-1]

# %%
test_normal_data_idx = math.ceil(df_normal.shape[0]/4)
train_normal = df_normal.iloc[test_normal_data_idx:]
test_normal = df_normal.iloc[:test_normal_data_idx-1]

# %%
test_viralPneumonia_data_idx = math.ceil(df_viralPneumonia.shape[0]/4)
train_viralPneumonia = df_viralPneumonia.iloc[test_viralPneumonia_data_idx:]
test_viralPneumonia = df_viralPneumonia.iloc[:test_viralPneumonia_data_idx-1]

# %%
train_data = pd.concat([train_covid,train_normal, train_viralPneumonia])
test_data = pd.concat([test_covid,test_normal,test_viralPneumonia])

# %%
train_data.reset_index()
# Out:
#       index                                             images          target
# 0      1757  ./COVID-19_Radiography_Dataset/COVID/masks/COV...        COVID-19
# 1      1758  ./COVID-19_Radiography_Dataset/COVID/masks/COV...        COVID-19
# 2      1759  ./COVID-19_Radiography_Dataset/COVID/masks/COV...        COVID-19
# 3      1760  ./COVID-19_Radiography_Dataset/COVID/masks/COV...        COVID-19
# 4      1761  ./COVID-19_Radiography_Dataset/COVID/masks/COV...        COVID-19
# ...     ...                                                ...             ...
# 9518   2648  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 9519   2649  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 9520   2650  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 9521   2651  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 9522   2652  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
#
# [9523 rows x 3 columns]

# %%
test_data.reset_index()
# Out:
#       index                                             images          target
# 0         0  ./COVID-19_Radiography_Dataset/COVID/masks/COV...        COVID-19
# 1         1  ./COVID-19_Radiography_Dataset/COVID/masks/COV...        COVID-19
# 2         2  ./COVID-19_Radiography_Dataset/COVID/masks/COV...        COVID-19
# 3         3  ./COVID-19_Radiography_Dataset/COVID/masks/COV...        COVID-19
# 4         4  ./COVID-19_Radiography_Dataset/COVID/masks/COV...        COVID-19
# ...     ...                                                ...             ...
# 3168    658  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 3169    659  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 3170    660  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 3171    661  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
# 3172    662  ./COVID-19_Radiography_Dataset/Viral Pneumonia...  ViralPneumonia
#
# [3173 rows x 3 columns]

# %%
train_data.to_csv('train_data.csv')
test_data.to_csv('test_data.csv')

# %%
train_data=pd.read_csv('train_data.csv')
test_data=pd.read_csv('test_data.csv')

# %%
#data augmantation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255,rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,horizontal_flip=True)

# Convert images to grayscale

val_datagen=ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    train_data,
    x_col='images',
    y_col='target',
    target_size=(256, 256),
    color_mode="grayscale",
    batch_size=32,
    shuffle=True,
    class_mode='sparse',
    validate_filenames=True)

validation_generator = val_datagen.flow_from_dataframe(
    test_data,
    x_col='images',
    y_col='target',
    target_size=(256, 256),
    shuffle=False,
    batch_size=32,
    color_mode="grayscale",
    class_mode='sparse',
    validate_filenames=True)
# Out:
# Found 9523 validated image filenames belonging to 3 classes.
# Found 3173 validated image filenames belonging to 3 classes.

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras import layers
from tensorflow.keras.metrics import AUC
from tensorflow.keras.activations import sigmoid
from tensorflow.keras.optimizers import SGD, Adam, Adamax
from tensorflow.keras import Model
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
      layers.Conv2D(64, 3, activation='relu', input_shape=(256, 256,1)),
      layers.MaxPooling2D(),
      layers.Dropout(0.3),
      layers.Conv2D(128,3,activation='relu'),
      layers.MaxPooling2D(),
      layers.Conv2D(256, 3, activation='relu'),
      layers.MaxPooling2D(),
      layers.Dropout(0.3),
      layers.Conv2D(512, 3, activation='relu'),
      layers.MaxPooling2D(),
      layers.Dropout(0.2),
      layers.Flatten(),
      layers.Dense(1024, activation='relu'),
      layers.Dropout(0.15),
      layers.Dense(3, activation= 'softmax')
    ])

# %%
import tensorflow.keras
from tensorflow.keras.metrics import AUC
opt = tensorflow.keras.optimizers.Adam(learning_rate = 1e-3)
model.compile(optimizer=opt,loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
nb_epochs = 50
batch_size=32

# %%
hist= model.fit(
    train_generator,
    epochs=nb_epochs,
    validation_data=validation_generator)
# Out:
# Epoch 1/10
# 222/222 [==============================] - 3434s 15s/step - loss: 1.1886 - accuracy: 0.5215 - val_loss: 1.0228 - val_accuracy: 0.4727
# Epoch 2/10
# 222/222 [==============================] - 3051s 14s/step - loss: 0.7962 - accuracy: 0.6323 - val_loss: 0.7860 - val_accuracy: 0.6885
# Epoch 3/10
# 222/222 [==============================] - 3042s 14s/step - loss: 0.7144 - accuracy: 0.6678 - val_loss: 0.6348 - val_accuracy: 0.7220
# Epoch 4/10
# 104/222 [=============>................] - ETA: 24:42 - loss: 0.6738 - accuracy: 0.6888

# %%
model.save('model.h5')

# %%
model.save_weights("model.hdf5")

# %%
TFlite_Model = tf.keras.models.load_model('model.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open("TFlite_Model.tflite", "wb").write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpfve6mol9/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 417261680
